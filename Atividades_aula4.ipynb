# %% [markdown]
# <a href="https://colab.research.google.com/github/willianbayer22/willianbayer22/blob/main/Atividades_aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ler números primos

número = int (input ("Qual o número?"))

if número % 2 == 0 or número % 3 == 0:
  print ("O número {} é primo " .format(número))
else:
  print ("O número {} não é primo " .format(número))
# Out:
# Qual o número?5
# O número 5 não é primo
