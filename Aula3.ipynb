# %% [markdown]
# <a href="https://colab.research.google.com/github/willianbayer22/willianbayer22/blob/main/Aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "willianbayer22"
# !git config --global user.email "willian.bayer@sou.unijui.edu.br"
# !git config --global init.defaulBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.email=willian.bayer@sou.unijui.edu.br
# user.name=willianbayer22
# init.defaulbranch=main

# %%
# !git clone https://github.com/willianbayer22/willianbayer22.git
# Out:
# Cloning into 'willianbayer22'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd willianbayer22
# !ls
# !git status
# !git remote -v
# Out:
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/willianbayer22/willianbayer22.git (fetch)
# origin	https://github.com/willianbayer22/willianbayer22.git (push)

# %%
# %%writefile README.md
#
# Arquivos da aula 03: Colab, GitHub e Git
#
# Willian Bayer
# Out:
# Overwriting README.md

# %%
# !git add README.md
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   README.md

# %%
# !git commit -m "OI, to testando"
# Out:
# [main c161a65] OI, to testando
#  1 file changed, 4 insertions(+), 16 deletions(-)
#  rewrite README.md (99%)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 310 bytes | 310.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/willianbayer22/willianbayer22.git
#    32259ea..c161a65  main -> main

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 95D1-4C16
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as willianbayer22
# github.com
#   ✓ Logged in to github.com account willianbayer22 (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %%
# !git pull origin main
# Out:
# From https://github.com/willianbayer22/willianbayer22
#  * branch            main       -> FETCH_HEAD
# Already up to date.
