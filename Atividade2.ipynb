# %% [markdown]
# <a href="https://colab.research.google.com/github/willianbayer22/willianbayer22/blob/main/Atividade2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "willianbayer22"
# !git config --global user.email "willian.bayer@sou.unijui.edu.br"
# !git config --global init.defaulBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=willianbayer22
# user.email=willian.bayer@sou.unijui.edu.br
# init.defaulbranch=main

# %%
aluno = (input ("Qual o nome do aluno "))
nota1 = float (input ("Qual a primeira nota do aluno? "))
nota2 = float (input ("Qual a segunda nota do aluno? "))
nota3 = float (input ("Qual a terceira nota do aluno? "))

soma = nota1 + nota2 + nota3
resultado = soma /3
print ("A media de notas do aluno é: ", resultado)
# Out:
# Qual o nome do aluno Willian
# Qual a primeira nota do aluno? 22
# Qual a segunda nota do aluno? 13
# Qual a terceira nota do aluno? 44
# A media de notas do aluno é:  26.333333333333332
