# %% [markdown]
# <a href="https://colab.research.google.com/github/willianbayer22/willianbayer22/blob/main/Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "willianbayer22"
# !git config --global user.email "willian.bayer@sou.unijui.edu.br"
# !git config --global init.defaulBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=willianbayer22
# user.email=willian.bayer@sou.unijui.edu.br
# init.defaulbranch=main

# %%
f = open("sample_data/README.md")

conteudo = f.readlines ()

f.close
# Out:
# <function TextIOWrapper.close()>

# %%
print (conteudo)
for linha in conteudo:
  print (linha)
# Out:
# ['This directory includes a few sample datasets to get you started.\n', '\n', '*   `california_housing_data*.csv` is California housing data from the 1990 US\n', '    Census; more information is available at:\n', '    https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub\n', '\n', '*   `mnist_*.csv` is a small sample of the\n', '    [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is\n', '    described at: http://yann.lecun.com/exdb/mnist/\n', '\n', '*   `anscombe.json` contains a copy of\n', "    [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it\n", '    was originally described in\n', '\n', "    Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American\n", '    Statistician. 27 (1): 17-21. JSTOR 2682899.\n', '\n', '    and our copy was prepared by the\n', '    [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e354998
# ...

# %%
conteudo .reverse()

novo_arquivo = open ('sample_data/LEIAME.txt','w')

novo_arquivo.writelines(conteudo)

novo_arquivo.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2584/4042540238.py in <cell line: 0>()
#       7 novo_arquivo.close()
#       8
# ----> 9 f1 = open("sample_data/LEIAME.md")
#      10
#      11 conteudo = f1.readlines ()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample_data/LEIAME.md'

# %%
with open ("sample_data/REAME.md", 'r') as f:
# Out:
#   File "/tmp/ipykernel_2584/2140881171.py", line 1
#     with open ("sample_data/REAME.md", 'r') as f:
#                                                  ^
# _IncompleteInputError: incomplete input

# %%
import json

pessoa = '{"nome": "Pedro", "linguagens": ["Espanhol", "Português"]}'

pessoa_dic = json.loads(pessoa)

print (pessoa_dic)

print (pessoa_dic['linguagens'])
# Out:
# {'nome': 'Pedro', 'linguagens': ['Espanhol', 'Português']}
# ['Espanhol', 'Português']

# %%
import json
with open ('sample_data/anscombe.json', 'r') as f:
  dados = json.load(f)

print (dados)

print (json.dumps(dados, indent = 4, sort_keys=True))
# Out:
# [{'Series': 'I', 'X': 10.0, 'Y': 8.04}, {'Series': 'I', 'X': 8.0, 'Y': 6.95}, {'Series': 'I', 'X': 13.0, 'Y': 7.58}, {'Series': 'I', 'X': 9.0, 'Y': 8.81}, {'Series': 'I', 'X': 11.0, 'Y': 8.33}, {'Series': 'I', 'X': 14.0, 'Y': 9.96}, {'Series': 'I', 'X': 6.0, 'Y': 7.24}, {'Series': 'I', 'X': 4.0, 'Y': 4.26}, {'Series': 'I', 'X': 12.0, 'Y': 10.84}, {'Series': 'I', 'X': 7.0, 'Y': 4.81}, {'Series': 'I', 'X': 5.0, 'Y': 5.68}, {'Series': 'II', 'X': 10.0, 'Y': 9.14}, {'Series': 'II', 'X': 8.0, 'Y': 8.14}, {'Series': 'II', 'X': 13.0, 'Y': 8.74}, {'Series': 'II', 'X': 9.0, 'Y': 8.77}, {'Series': 'II', 'X': 11.0, 'Y': 9.26}, {'Series': 'II', 'X': 14.0, 'Y': 8.1}, {'Series': 'II', 'X': 6.0, 'Y': 6.13}, {'Series': 'II', 'X': 4.0, 'Y': 3.1}, {'Series': 'II', 'X': 12.0, 'Y': 9.13}, {'Series': 'II', 'X': 7.0, 'Y': 7.26}, {'Series': 'II', 'X': 5.0, 'Y': 4.74}, {'Series': 'III', 'X': 10.0, 'Y': 7.46}, {'Series': 'III', 'X': 8.0, 'Y': 6.77}, {'Series': 'III', 'X': 13.0, 'Y': 12.74}, {'Series': 'III', 
# ...

# %%
pessoa_add = {"casado": True, "idade": 32}

pessoa_dic.update(pessoa_add)

with open ('sample_data/pessoa.txt', 'w') as json_file:
  (json.dump(pessoa_dic, json_file, indent = 4, sort_keys=True))

# %%
import json
import requests

resposta = requests.get("https://api.randomuser.me/")

print (resposta.status_code)

print (resposta.text)
# Out:
# 200
# ...

# %%
dados = json.loads(resposta.text)

print (dados)

print (json.dumps(dados, indent = 4, sort_keys=True))
# Out:
# {'results': [{'gender': 'male', 'name': {'title': 'Mr', 'first': 'Jacob', 'last': 'Bergeron'}, 'location': {'street': {'number': 9041, 'name': 'Concession Road 23'}, 'city': 'Westport', 'state': 'Nunavut', 'country': 'Canada', 'postcode': 'U6Y 3Z5', 'coordinates': {'latitude': '-64.6192', 'longitude': '-76.8235'}, 'timezone': {'offset': '+7:00', 'description': 'Bangkok, Hanoi, Jakarta'}}, 'email': 'jacob.bergeron@example.com', 'login': {'uuid': '71de4f9d-63a6-4787-8905-baf3fbee6419', 'username': 'angryfrog761', 'password': 'mariposa', 'salt': 'zoPxCHDb', 'md5': '650b4c6aa3003c07ce7e3ce7f1a7a82b', 'sha1': '5623b0e7af2528cd1742acc0a85189658ea25543', 'sha256': '05b3436d5a619bd581d4d87e81fd232c14cf984b6e375f41e13a13566b44047c'}, 'dob': {'date': '1982-10-05T14:09:39.682Z', 'age': 43}, 'registered': {'date': '2022-03-10T11:39:59.724Z', 'age': 4}, 'phone': 'Y79 X32-1542', 'cell': 'F27 A06-6974', 'id': {'name': 'SIN', 'value': '890097793'}, 'picture': {'large': 'https://randomuser.me/api/por
# ...

# %%
import csv

with open ('sample_data/california_housing_test.csv', 'r') as f:
  leitor = csv.reader(f,delimiter= ',')
  for linha in leitor :
    total_quartos= linha[3]
    print (total_quartos)
# Out:
# population
# 1537.000000
# 809.000000
# 1484.000000
# 49.000000
# 850.000000
# 663.000000
# 604.000000
# 1341.000000
# 1446.000000
# 2830.000000
# 1288.000000
# 564.000000
# 535.000000
# 1935.000000
# 1217.000000
# 157.000000
# 189.000000
# 1603.000000
# 654.000000
# 3450.000000
# 849.000000
# 937.000000
# 1651.000000
# 1410.000000
# 4049.000000
# 667.000000
# 2259.000000
# 1030.000000
# 3751.000000
# 1561.000000
# 568.000000
# 1530.000000
# 1693.000000
# 8152.000000
# 499.000000
# 2650.000000
# 700.000000
# 956.000000
# 883.000000
# 2760.000000
# 961.000000
# 1269.000000
# 697.000000
# 737.000000
# 835.000000
# 3925.000000
# 799.000000
# 1003.000000
# 732.000000
# 3554.000000
# 4356.000000
# 426.000000
# 1109.000000
# 883.000000
# 892.000000
# 779.000000
# 1932.000000
# 1825.000000
# 676.000000
# 1969.000000
# 445.000000
# 1055.000000
# 1026.000000
# 776.000000
# 1204.000000
# 1640.000000
# 3559.000000
# 728.000000
# 2767.000000
# 1265.000000
# 930.000000
# 1998.000000
# ...

# %%
# !git config --global user.name "willianbayer22"
# !git config --global user.email "willian.bayer@sou.unijui.edu.br"
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com
--git-protocol https --web
# !gh auth setup-git
# !git clonehttps://github.com/willianbayer22/willianbayer22.git
# %cd SEU_REPOSITORIO
# !git add .
# !git commit -m "Atualização"
# !git push
# Out:
#   File "/tmp/ipykernel_2584/1765800660.py", line 6
#     --git-protocol https --web
#                    ^
# SyntaxError: invalid syntax
